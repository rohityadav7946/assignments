# %%
#QUESTION 1
import pandas as pd

info = {'Name':['Rohit','Nikhil','Krishan','Deepak','Kartikey'],'Age':[20,20,19,21,22],'Ph no.':['8527378713','9876874587','9845786642','8769054563','7890123456'],'Email':['rohityadav7946@gmail.com','nikhil@gmail.com','krishan@gmail.com','deepak@gmail.com','kartikey@gmail.com']}

df=pd.DataFrame(info)
df = df[['Name','Age','Ph no.','Email']]
print(df)

df.loc[5]=['Kshitij',19,'9874563210','kshitij@gmail.com']
print(df)
# Out:
#        Name  Age      Ph no.                     Email
# 0     Rohit   20  8527378713  rohityadav7946@gmail.com
# 1    Nikhil   20  9876874587          nikhil@gmail.com
# 2   Krishan   19  9845786642         krishan@gmail.com
# 3    Deepak   21  8769054563          deepak@gmail.com
# 4  Kartikey   22  7890123456        kartikey@gmail.com
#        Name  Age      Ph no.                     Email
# 0     Rohit   20  8527378713  rohityadav7946@gmail.com
# 1    Nikhil   20  9876874587          nikhil@gmail.com
# 2   Krishan   19  9845786642         krishan@gmail.com
# 3    Deepak   21  8769054563          deepak@gmail.com
# 4  Kartikey   22  7890123456        kartikey@gmail.com
# 5   Kshitij   19  9874563210         kshitij@gmail.com

# %%
#QUESTION2
weather = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
#QUESTION 2(a)
weather.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#QUESTION 2(b)
weather.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
#QUESTION 2(c)
weather.iloc[0:15,0:10].describe()
# Out:
#         MinTemp    MaxTemp   Rainfall  Evaporation   Sunshine  WindGustSpeed
# count  15.00000  15.000000  15.000000    15.000000  15.000000      15.000000
# mean    9.62000  22.873333   4.426667     5.666667   8.993333      43.400000
# std     2.56632   5.386553  10.644883     1.490286   3.315864      13.725888
# min     6.10000  15.500000   0.000000     3.400000   3.300000      30.000000
# 25%     8.15000  17.600000   0.000000     4.300000   7.000000      35.000000
# 50%     8.80000  23.400000   0.000000     5.600000   9.100000      41.000000
# 75%    11.10000  27.100000   3.200000     6.700000  12.150000      46.000000
# max    14.00000  31.200000  39.800000     8.800000  13.100000      85.000000

# %%
#QUESTION 2(d)
weather.tail()
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
#QUESTION 2(e)
weather.iloc[:,1].describe()
# Out:
# count          366
# unique           1
# top       Canberra
# freq           366
# Name: Location, dtype: object
