# %%
#QUESTION 1
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.countplot(x='Date', data=df)
plt.title("1.Count plot of Date")
# Out:
# Text(0.5,1,'1.Count plot of Date')

# %%
sns.distplot(df['MinTemp'])
plt.title("2.Dist plot of MinTemp")
# Out:
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'2.Dist plot of MinTemp')

# %%
sns.countplot(x='MaxTemp', data=df)
plt.title("3.Count plot of MaxTemp")
# Out:
# Text(0.5,1,'3.Count plot of MaxTemp')

# %%
sns.distplot(df['Rainfall'])
plt.title("4.Dist plot of Rainfall")
# Out:
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'4.Dist plot of Rainfall')

# %%
sns.boxplot(x= 'WindSpeed9am', y='WindSpeed3pm',data=df, hue='RainToday')
plt.title("5.plot of  'WindSpeed9am','WindSpeed3pm'")
# Out:
# Text(0.5,1,"5.plot of  'WindSpeed9am','WindSpeed3pm'")

# %%
sns.jointplot(x= 'Humidity9am', y='Humidity3pm',data=df)
plt.title("6.plot of  'Humidity9am','Humidity3pm'")
# Out:
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,"6.plot of  'Humidity9am','Humidity3pm'")

# %%
sns.boxplot(x='Evaporation', y='Sunshine',data=df)
plt.title("7.Box plot of 'Evaporation','Sunshine',")
# Out:
# Text(0.5,1,"7.Box plot of 'Evaporation','Sunshine',")

# %%
sns.jointplot(x='Evaporation', y='Sunshine',data=df, alpha=0.2)
plt.title("8. plot of 'WindGustDir','WindGustSpeed'")
# Out:
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,"8. plot of 'WindGustDir','WindGustSpeed'")

# %%
df['RISK_MM'].plot(kind='barh')
plt.title("9.plot of RISK_MM")
# Out:
# Text(0.5,1,'9.plot of RISK_MM')

# %%
sns.violinplot(x= 'Pressure9am', y='RainTomorrow',data=df)
plt.title("10.plot of  'Pressure9am','RainTomorrow'")
# Out:
# Text(0.5,1,"10.plot of  'Pressure9am','RainTomorrow'")

# %%
sns.violinplot(x= 'WindDir9am', y='WindSpeed9am',data=df, hue='RainTomorrow',inner='stick')
plt.title("11.plot of  'WindDir9am','WindSpeed9am'")
# Out:
# Text(0.5,1,"11.plot of  'WindDir9am','WindSpeed9am'")

# %%
sns.boxplot(x= 'WindDir9am', y='Temp3pm',data=df,palette='Set2')
plt.title("12.plot of  'WindDir9am','Temp3pm'")
# Out:
# Text(0.5,1,"12.plot of  'WindDir9am','Temp3pm'")

# %%
sns.violinplot(x= 'Temp9am', y='Temp3pm',data=df,hue='RainToday' ,split= True, inner='stick',palette='Set2')
plt.title("13. plot of  'Temp9am','Temp3pm'")
# Out:
# Text(0.5,1,"13. plot of  'Temp9am','Temp3pm'")

# %%
sns.violinplot(x= 'RainToday', y='WindSpeed9am',data=df, hue='RainTomorrow',split=True,inner='stick')
plt.title("14. plot of  'RainToday','WindSpeed9am'")
# Out:
# Text(0.5,1,"14. plot of  'RainToday','WindSpeed9am'")

# %%
sns.jointplot(x= 'Pressure3pm', y='Humidity3pm',data=df)
plt.title("15.plot of  'Pressure3pm','Humidity3pm'")
# Out:
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rohit\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,"15.plot of  'Pressure3pm','Humidity3pm'")

# %%
df['Rainfall'].plot(kind='pie')

# %%
df['Sunshine'].plot(kind='barh')

# %%
df['Evaporation'].plot(kind='pie')

# %%
df['WindSpeed3pm'].plot(kind='bar')

# %%
sns.jointplot(x= 'Humidity9am', y='Humidity3pm',data=df, kind="kde");

# %%
plt.hist(df['MinTemp'])
# Out:
# (array([13., 38., 51., 47., 42., 47., 52., 49., 25.,  2.]),
#  array([-5.3 , -2.68, -0.06,  2.56,  5.18,  7.8 , 10.42, 13.04, 15.66,
#         18.28, 20.9 ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(df['MinTemp'], df['MaxTemp'])

# %%
sns.kdeplot(df['MaxTemp'],shade=True, color="g")

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['MaxTemp'], df['MinTemp'])

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(df['MaxTemp'], df['MinTemp'], shade=True)

# %%
sns.lmplot(x='MaxTemp', y='MinTemp', data=df)

# %%
plt.figure(figsize=(10,8))
sns.stripplot(x='MaxTemp', y='MinTemp', data=df)

# %%
plt.figure(figsize=(10,8))
sns.swarmplot(x='MaxTemp', y='MinTemp', data=df)

# %%
plt.figure(figsize=(10,8))
corr= df.corr()
sns.heatmap(corr)
